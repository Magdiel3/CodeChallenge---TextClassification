# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import spacy

# %%
#Spacy
nlp = spacy.load('de_core_news_sm')

#Read and format dataset
with open("C:\Users\magdi\OneDrive\Documents\VSCode\Python\miniDataSet.json",encoding="utf8", errors='ignore') as f:
    data = json.load(f)       
        
df = pd.DataFrame.from_dict(data["data"])

df.head(10)
# Out:
#   File "<ipython-input-21-72c874036cb8>", line 5
#     with open("C:\Users\magdi\OneDrive\Documents\VSCode\Python\miniDataSet.json", 'r',encoding = 'utf8', errors="ignore") as f:
#              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
#Plot distribution of data
size = df.groupby("label").size().tolist()

_, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

plt.pie(size,labels = ["none","soft","tech"], 
        wedgeprops = {'linewidth': 3},
        autopct='%1.1f%%',
        startangle = 15)

ax.set_title("Distribution of the data")

plt.show()

# %%
from collections import Counter

#Get most common words for bag of words
alltext = ""
for d in df["text"]:
    alltext += d
doc = nlp(alltext)
words = [token.text for token in doc if token.is_stop != True and token.is_punct != True 
         and token.like_num != True and token.pos_ != "SYM" and token.shape_[0:3].lower() == 'xxx']

word_freq = Counter(words)
common_words = word_freq.most_common(5000)
word_features = [t[0] for t in common_words]

# %%
#define feature vectors
def find_features(doc):
    words = doc
    features = []
    for w in word_features:
        features.append(1 if (w in words) else 0)
    return features

# %%
import numpy as np

#Extract feature vectors for each text entry with its corresponding label
featuresets = np.array([(find_features(df["text"][index]), df["label"][index]) for index,_ in df.iterrows()])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

#Prepare data for training
X = np.array([x[0] for x in featuresets[:]])
Y = [x[1] for x in featuresets[:]]

#Label Encoding
le = LabelEncoder().fit(Y)
Y = np.array(le.transform(Y))
    
trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.25)

# %%
#Prediction with Multinomial Naive Bayes 
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer

clf = MultinomialNB()
clf.fit(trainX, trainY)
accuaracy = clf.score(testX,testY)
print("Accuarcy: {0:.3%}".format(accuaracy))
# Out:
# Accuarcy: 92.548%

# %%
#Generae Confusion matrix to visualize data classification
from sklearn.metrics import plot_confusion_matrix

def plot_conf_mat(est,X,Y):
    disp = 0
    disp = plot_confusion_matrix(est, X, Y,
                                 display_labels = ["none","soft","tech"],
                                 cmap = plt.cm.Blues,
                                 normalize = "true")
    disp.ax_.set_title("Normalized confusion matrix")

    plt.show()

# %%
#Plot confusion matrix for this model
plot_conf_mat(clf,testX,testY)

# %% [markdown]
# Despite different train/test spliting ratios and word features selected, couldn't improve more than 95%

# %% [markdown]
# New model to train: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

#LogisticRegression model and training
clflr = LogisticRegression(solver = 'newton-cg', multi_class = 'multinomial')
clflr.fit(trainX, trainY)
accuaracy = clflr.score(testX,testY)

print("Accuarcy: {0:.3%}".format(accuaracy))
# Out:
# Accuarcy: 93.211%

# %%
#Plot confusion matrix for this model
plot_conf_mat(clflr,testX,testY)

# %% [markdown]
# Bow let's try with a Neural Network (1-hidden-layer)

# %%
from sklearn.preprocessing import OneHotEncoder

#Prepare data for training
X = np.array([x[0] for x in featuresets[:]])
Y = [x[1] for x in featuresets[:]]

#One-hot-encoding
enc = OneHotEncoder(sparse = False)
Y = enc.fit_transform(np.array(Y).reshape(-1,1))
    
trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.25)

# %%
from keras.models import Sequential
from keras import layers
import tensorflow

input_dim = trainX.shape[1]  # Number of features

model = Sequential()
model.add(layers.Dense(120, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
model.summary()
# Out:
# Using TensorFlow backend.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 120)               600120
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 363
# =================================================================
# Total params: 600,483
# Trainable params: 600,483
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(trainX, trainY,
                    verbose = 1,
                    epochs=15,
                    validation_data = (testX,testY),
                    batch_size=500)
# Out:
# Train on 7686 samples, validate on 2563 samples
# Epoch 1/15
# 7686/7686 [==============================] - 2s 228us/step - loss: 0.9291 - accuracy: 0.8263 - val_loss: 0.7204 - val_accuracy: 0.9208
# Epoch 2/15
# 7686/7686 [==============================] - 1s 100us/step - loss: 0.5866 - accuracy: 0.9305 - val_loss: 0.4575 - val_accuracy: 0.9341
# Epoch 3/15
# 7686/7686 [==============================] - 1s 98us/step - loss: 0.3814 - accuracy: 0.9405 - val_loss: 0.3302 - val_accuracy: 0.9438
# Epoch 4/15
# 7686/7686 [==============================] - 1s 100us/step - loss: 0.2771 - accuracy: 0.9523 - val_loss: 0.2678 - val_accuracy: 0.9493
# Epoch 5/15
# 7686/7686 [==============================] - 1s 108us/step - loss: 0.2177 - accuracy: 0.9573 - val_loss: 0.2344 - val_accuracy: 0.9469
# Epoch 6/15
# 7686/7686 [==============================] - 1s 101us/step - loss: 0.1794 - accuracy: 0.9625 - val_loss: 0.2148 - val_accuracy: 0.9473
# Epoch 7/15
# 7686/7686 [==============================] - 1s 100us/step - loss: 0.1525 - accuracy: 0.9677 - val_loss: 0.2021 - val_accuracy: 0.9489
# Epoch 8/15
# 7686/7686 [==============================] - 1s 104us/step - loss: 0.1330 - accuracy: 0.9711 - val_loss: 0.1935 - val_accuracy: 0.9481
# Epoch 9/15
# 7686/7686 [==============================] - 1s 97us/step - loss: 0.1178 - accuracy: 0.9733 - val_loss: 0.1889 - val_accuracy: 0.9489
# Epoch 10/15
# 7686/7686 [==============================] - 1s 114us/step - loss: 0.1060 - accuracy: 0.9765 - val_loss: 0.1868 - val_accuracy: 0.9481
# Epoch 11/15
# 7686/7686 [==============================] - 1s 102us/step - loss: 0.0964 - accuracy: 0.9778 - val_loss: 0.1858 - val_accuracy: 0.9473
# Epoch 12/15
# 7686/7686 [==============================] - 1s 99us/step - loss: 0.0884 - accuracy: 0.9791 - val_loss: 0.1858 - val_accuracy: 0.9469
# Epoch 13/15
# 7686/7686 [==============================] - 1s 98us/step - loss: 0.0818 - accuracy: 0.9806 - val_loss: 0.1866 - val_accuracy: 0.9469
# Epoch 14/15
# 7686/7686 [==============================] - 1s 103us/step - loss: 0.0763 - accuracy: 0.9811 - val_loss: 0.1887 - val_accuracy: 0.9477
# Epoch 15/15
# 7686/7686 [==============================] - 1s 118us/step - loss: 0.0715 - accuracy: 0.9826 - val_loss: 0.1899 - val_accuracy: 0.9473

# %%
#history_dict = history.history
#history_dict.keys()

plt.subplot(2,1,1)
# Plot training & validation accuracy values
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

plt.subplot(2,1,2)
# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

#Had to make the confusion matrix myself as I couldn0t use the previous one
sns.set()
cm=confusion_matrix(enc.inverse_transform(testY),enc.inverse_transform(model.predict(testX)))

row_sums = cm.sum(axis=1)
cm_norm = cm / row_sums[:, np.newaxis]

sns.set(font_scale=1.2)
ax = sns.heatmap(cm_norm, annot=True, vmin = 0, vmax = 1,
                cmap = plt.cm.Blues, square = True,
                xticklabels=["none","soft","tech"],
                yticklabels=["none","soft","tech"])

ax.set_title("Normalized confusion matrix")
ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)

plt.show()

# %%
#Just to check i'll use some personal Anschreiben texts 
#It's extra just for "fun"

rawData = "Für mich bedeutet die Zusammenarbeit mit Ihnen eine berufliche Koalition aneignen, wo ich mir eine so bekannte Arbeitskultur Ihres Unternehmen, und mit meiner gesammelten Erfahrung arbeiten kann"
newData = np.asarray(find_features(rawData))

newData = newData.reshape(1,-1)

predLabel = np.zeros(3)
predIndex = np.argmax(model.predict([newData]))
predLabel[predIndex] = 1

predLabel = predLabel.reshape(1,-1)

predLabelStr = enc.inverse_transform(predLabel)[0][0]

print(rawData + " =======> " + predLabelStr)
# Out:
# Für mich bedeutet die Zusammenarbeit mit Ihnen eine berufliche Koalition aneignen, wo ich mir eine so bekannte Arbeitskultur Ihres Unternehmen, und mit meiner gesammelten Erfahrung arbeiten kann =======> none

# %%
#Save current model trained model
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
#Save vector of features
import pickle
import os
with open('C:/Users/magdi/OneDrive/Documents\VSCode\Python\Talentbait\CodeChallenge---TextClassification\model\word_features', 'rb') as f:
    print(pickle.load(f))
# Out:
# ['Kenntnisse', 'GmbH', 'Umgang', 'Arbeitsweise', 'Bereich', 'Wort', 'Englischkenntnisse', 'Standort', 'Teamfähigkeit', 'Bewerbung', 'Auftreten', 'freuen', 'Flexibilität', 'suchen', 'hohe', 'Schrift', 'verfügen', 'Office', 'per', 'Kontakt', 'Unternehmen', 'Profil', 'gerne', 'Fähigkeiten', 'Kunden', 'SAP', 'Maß', 'Deutschland', 'Angabe', 'analytische', 'strukturierte', 'Belastbarkeit', 'arbeiten', 'Bereitschaft', 'Hamburg', 'Frau', 'hohes', 'Denken', 'Team', 'Deutsch-', 'ausgeprägte', 'runden', 'Engagement', 'Eigeninitiative', 'Kommunikations-', 'Englisch', 'Mitarbeiter', 'insbesondere', 'Arbeiten', 'selbstständige', 'nächstmöglichen', 'besitzen', 'Verständnis', 'Durchsetzungsvermögen', 'Gehaltsvorstellung', 'Bewerbungsunterlagen', 'bewerben', 'Fähigkeit', 'Hohe', 'and', 'gängigen', 'bitte', 'unseren', 'Excel', 'Kommunikationsfähigkeit', 'wünschenswert', 'Freude', 'Informationen', 'Interesse', 'München', 'Einsatzbereitschaft', 'Kommunikationsstärke', 'Zuverlässigkeit', 'Vorteil', 'Berlin', 'Kompetenz', 'Arbeit', 'Deutsch', 'Bitte', 'Eintrittstermins', 'zeichnen', 'Fragen', 'Vollzeit', 'internationalen', 'steht', 'sicheres', 'Ausgeprägte', 'frühestmöglichen', 'kommunikative', 'Frankfurt', 'Zeitpunkt', 'Verfügung', 'Entwicklung', 'Jobs', 'Tel.', 'unseres', 'senden', 'Telefon', 'finden', 'Karriere', 'Persönlichkeit', 'Job', 'Spaß', 'Sicherer', 'Teams', 'Microsoft', 'Kundenorientierung', 'Management', 'Herr', 'Reisebereitschaft', 'Verantwortungsbewusstsein', 'Menschen', 'online', 'bringen', 'jobs', 'your', 'Deutschkenntnisse', 'Fundierte', 'Bereichen', 'for', 'the', 'Arbeitgeber', 'Verhandlungsgeschick', 'Handeln', 'Berufserfahrung', 'idealerweise', 'Lebenslauf', 'Spezial', 'soziale', 'Auffassungsgabe', 'Sprachkenntnisse', 'Stelle', 'Service', 'Group', 'setzen', 'Aufgaben', 'Verstärkung', 'Sprache', 'Facebook', 'technisches', 'Klasse', 'konzeptionelle', 'aussagekräftigen', 'analytisches', 'Word', 'Stellenangebote', 'Engineering', 'Software', 'Organisationstalent', 'Amadeus', 'bevorzugt', 'Düsseldorf', 'Fax', 'eigenverantwortliche', 'FiRe', 'weltweit', 'Produkte', 'Stuttgart', 'sicher', 'Bewerber', 'bzw.', 'Technologien', 'Germany', 'Zusammenarbeit', 'Teamgeist', 'Twitter', 'Team-', 'Services', 'komplexe', 'Denkvermögen', 'persönlichen', 'Windows', 'Google', 'Hohes', 'zielorientierte', 'Ansprechpartner', 'bieten', 'Position', 'Unterlagen', 'unserem', 'sofort', 'entwickeln', 'Impressum', 'Datenschutz', 'Köln', 'Kreativität', 'Kommunikationsfähigkeiten', 'Kennziffer', 'Kunden-', 'Selbstständige', 'Eigenmotivation', 'Media', 'sorgfältige', 'überzeugen', 'Einsatz', 'Interessiert', 'hoher', 'erfolgreich', 'EDV-Kenntnisse', 'Daten', 'geweckt', 'schnell', 'Kommunikation', 'selbstverständlich', 'Gruppe', 'guten', 'Forschung', 'sucht', 'Niederlassung', 'Manager', 'Mitarbeitern', 'aussagekräftige', 'Eintrittstermin', 'Bad', 'Zukunft', 'Know-how', 'Wissen', 'LinkedIn', 'SQL', 'Business', 'Umfeld', 'selbständige', 'Projektmanagement', 'schnelle', 'Java', 'Grundkenntnisse', 'Human', 'technische', 'direkt', 'Geschick', 'strukturiert', 'Standorten', 'nutzen', 'zuverlässige', 'Themen', 'Str.', 'deutschen', 'Affinität', 'freundliches', 'Vertrieb', 'Teamplayer', 'Life', 'flexibel', 'Nutzen', 'bundesweit', 'Leistungen', 'technischen', 'selbstständig', 'sichere', 'Main', 'PowerPoint', 'Recruiting', 'Sciences', 'Social', 'Serviceorientierung', 'ausgeprägtes', 'vollständigen', 'Center', 'vorzugsweise', 'nationalen', 'Online-Bewerbungsformular', 'Weiterbildung', 'Leistungsbereitschaft', 'Straße', 'Data', 'AGB', 'Ausbildung', 'beherrschen', 'führenden', 'Berufseinstieg', 'gilt', 'englischen', 'verbindliches', 'Server', 'Cookies', 'Verantwortung', 'vertraut', 'hinaus', 'Lernbereitschaft', 'Eignung', 'Strukturierte', 'Follow', 'Partner', 'Erfahrung', 'Anwendung', 'hohen', 'international', 'und/oder', 'Erfolg', 'Phone', 'Überblick', 'Teamorientierung', 'Einstieg', 'max.', 'fundierte', 'Lösungen', 'fachliche', 'Sicheres', 'Idealerweise', 'Currently', 'available ...
